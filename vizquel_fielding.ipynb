# %%
#Esta no pude hacerla con web scrapping, así que descargué los datos en un excel.

import pandas as pd

ruta_excel = r'C:\Users\orlan\Documents\EDA\Vizquel\Estadisticas defensa.xlsx'
df_vizquel_defensa = pd.read_excel(ruta_excel)
print(df_vizquel_defensa)
# Out:
#     Year  Age   Tm Pos  Lg    G   GS     CG     Inn     Ch  ...  Rtot  Rdrs  \
# 0   1989   22  SEA  SS  AL  143  131   95.0  1124.0  614.0  ...   6.0   NaN
# 1   1990   23  SEA  SS  AL   81   78   67.0   680.0  349.0  ...  13.0   NaN
# 2   1991   24  SEA  SS  AL  138  123  114.0  1134.1  659.0  ...  14.0   NaN
# 3   1991   24  SEA  2B  AL    1    0    0.0     1.0    0.0  ...   NaN   NaN
# 4   1992   25  SEA  SS  AL  136  128  120.0  1152.0  633.0  ...  13.0   NaN
# 5   1993   26  SEA  SS  AL  155  150  140.0  1330.2  735.0  ...  16.0   NaN
# 6   1993   26  SEA  DH  AL    2    0    NaN     NaN    NaN  ...   NaN   NaN
# 7   1994   27  CLE  SS  AL   69   68   66.0   612.2  323.0  ...   4.0   NaN
# 8   1995   28  CLE  SS  AL  136  135  125.0  1187.0  624.0  ...   1.0   NaN
# 9   1996   29  CLE  SS  AL  150  149  135.0  1312.1  693.0  ...   1.0   NaN
# 10  1997   30  CLE  SS  AL  152  149  141.0  1307.1  684.0  ...   2.0   NaN
# ...

# %%
df_vizquel_defensa
# Out:
#     Year  Age   Tm Pos  Lg    G   GS     CG     Inn     Ch  ...  Rtot  Rdrs  \
# 0   1989   22  SEA  SS  AL  143  131   95.0  1124.0  614.0  ...   6.0   NaN
# 1   1990   23  SEA  SS  AL   81   78   67.0   680.0  349.0  ...  13.0   NaN
# 2   1991   24  SEA  SS  AL  138  123  114.0  1134.1  659.0  ...  14.0   NaN
# 3   1991   24  SEA  2B  AL    1    0    0.0     1.0    0.0  ...   NaN   NaN
# 4   1992   25  SEA  SS  AL  136  128  120.0  1152.0  633.0  ...  13.0   NaN
# 5   1993   26  SEA  SS  AL  155  150  140.0  1330.2  735.0  ...  16.0   NaN
# 6   1993   26  SEA  DH  AL    2    0    NaN     NaN    NaN  ...   NaN   NaN
# 7   1994   27  CLE  SS  AL   69   68   66.0   612.2  323.0  ...   4.0   NaN
# 8   1995   28  CLE  SS  AL  136  135  125.0  1187.0  624.0  ...   1.0   NaN
# 9   1996   29  CLE  SS  AL  150  149  135.0  1312.1  693.0  ...   1.0   NaN
# 10  1997   30  CLE  SS  AL  152  149  141.0  1307.1  684.0  ...   2.0   NaN
# ...

# %%
#Aquí supe cuantas y cuales columnas había y saber cuales iba a quitar

df_vizquel_defensa.columns
# Out:
# Index(['Year', 'Age', 'Tm', 'Pos', 'Lg', 'G', 'GS', 'CG', 'Inn', 'Ch', 'PO',
#        'A', 'E', 'DP', 'Fld%', 'Rtot', 'Rdrs', 'Rtot/yr', 'Rdrs/yr', 'RF/9',
#        'RF/G', 'lgFld%', 'lgRF9', 'lgRFG', 'Awards'],
#       dtype='object')

# %%
#Usé .loc para escoger

df_vizquel_defensa_filtrado = df_vizquel_defensa.loc[:, ['Fld%', 'A', 'DP', 'E']]

df_vizquel_defensa_filtrado
# Out:
#         Fld%      A     DP     E
# 0      0.971  388.0  102.0  18.0
# 1      0.980  239.0   48.0   7.0
# 2      0.980  422.0  105.0  13.0
# 3        NaN    0.0    0.0   0.0
# 4      0.989  403.0   92.0   7.0
# 5      0.980  475.0  108.0  15.0
# 6        NaN    NaN    NaN   NaN
# 7      0.981  204.0   54.0   6.0
# 8      0.986  405.0   84.0   9.0
# 9      0.971  447.0   91.0  20.0
# 10     0.985  429.0   98.0  10.0
# 11     0.993  442.0   94.0   5.0
# 12     0.976  396.0   88.0  15.0
# 13       NaN    0.0    0.0   0.0
# 14       NaN    0.0    0.0   0.0
# 15     0.995  414.0   99.0   3.0
# 16     0.989  414.0   88.0   7.0
# 17     0.990  431.0   98.0   7.0
# 18     0.978  203.0   59.0   7.0
# 19     0.982  396.0   91.0  11.0
# 20     0.988  426.0   81.0   8.0
# 21     0.993  390.0   87.0   4.0
# 22     0.986  444.0   90.0   9.0
# 23     0.993  179.0   43.0   2.0
# 24  1000.000   76.0   22.0   0.0
# 25  1000.000   22.0    2.0   0.0
# 26  1000.000   49.0   12.0   0.0
# ...
